# %%
# Taks 1:

age = 17

if age < 18:
    print("Minor")
elif 18 <= age < 60:
    print("Adult")
else:
    print("Senior")
# Out:
# Minor

# %%
# Taks 2:
marks = 105

if marks < 0 or marks > 100:
    print("Invalid marks")
elif marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Invalid marks

# %%
# Taks 3:
data = []

if data is not None:
    print("No data")
else:
    print("Data available")
# Out:
# No data

# %%
# Taks 4:
value = "123a"

try:
    int_value = int(value)
except ValueError:
    print("Invalid Number")
else:
    print(int_value)
# Out:
# Invalid Number

# %%
# Taks 5:
values = ["10", "20", "abc", "30", "", "40"]

valid_int_values = []
for value in values:
    try:
        value_int = int(value)
    except ValueError:
        continue
    else:
        valid_int_values.append(value_int)
        # value_int += value_int
        # print(value_int)
        # value_int += value_int
        # print(value_int)


print(valid_int_values)

for i in valid_int_values:
    i += i
    print(i)
# print(value_int)
print(sum(valid_int_values))
# Out:
# [10, 20, 30, 40]
# 20
# 40
# 60
# 80
# 100

# %%
# Taks 6:
nums = [10, -5, 20, -3, 30]

for i in nums:
    if i < 0:
        continue
    else:
        print(i)
# Out:
# 10
# 20
# 30

# %%
# Taks 7:
nums = [5, 10, 0, 20, 30]

for i in nums:
    if i == 0:
        break
    else:
        print(i)
# Out:
# 5
# 10

# %%
# Taks 8:
password = "admin123"

# for i in password:
#     print(i)
password_len = len(password)
# print(password_len)

if password_len < 8:
    print("Weak Password")
else:
    print("Strong password")
# Out:
# 8
# Strong password

# %%
# Taks 9:
user = {"name": "Amit", "age": 30}

# print(user["city"])

try:
    # print(user["city"])
    if "city" in user:
except ValueError:
    print("City not found")
else:
    print(user["city"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 6
#       3 # print(user["city"])
#       5 try:
# ----> 6     print(user["city"])
#       7 except ValueError:
#       8     print("City not found")
#
# KeyError: 'city'

# %%
# Taks 10:
# Why is try/except important in data-related jobs?

# i think try except is veru useful in coding world, as sometimes we do not what comes in the input and our function is not ready to handle that, so instead of giving user the error Code,
# we can actually tell the user that there is some problem please try again. a simple user does not understand error codes like developers do.
# i am still confused at try except part, but i will pick it up this soon enoiugh

# %%
list1 = ['ginger', 'balck', 'milk']
l = list(enumerate(list1))
print(l)
# Out:
# [(0, 'ginger'), (1, 'balck'), (2, 'milk')]

# %%
number = 10

def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1) 



fact = factorial(number)

print(f"The factorial of {number} is: {fact}")
# Out:
# The factorial of 10 is: 3628800

# %%
food = "Pizza"
print(food)
food =food.replace("z", "s")
print(food)
# Out:
# Pizza
# Pissa
